# %%
from fastai import *
from fastai.text import *
bs=128
data_path = Config.data_path()

# %%
def get_wiki(path,lang):
    name = f'{lang}wiki'
    if (path/name).exists():
        print(f"{path/name} already exists; not downloading")
        return

    xml_fn = f"{lang}wiki-latest-pages-articles.xml"
    zip_fn = f"{xml_fn}.bz2"

    if not (path/xml_fn).exists():
        print("downloading...")
        download_url(f'https://dumps.wikimedia.org/{name}/latest/{zip_fn}', path/zip_fn)
        print("unzipping...")
        bunzip(path/zip_fn)

    with working_directory(path):
        if not (path/'wikiextractor').exists(): os.system('git clone https://github.com/attardi/wikiextractor.git')
        print("extracting...")
        os.system("python wikiextractor/WikiExtractor.py --processes 4 --no_templates " +
            f"--min_text_length 1800 --filter_disambig_pages --log_file log -b 100G -q {xml_fn}")
    shutil.move(str(path/'text/AA/wiki_00'), str(path/name))
    shutil.rmtree(path/'text')


def split_wiki(path,lang):
    dest = path/'docs'
    name = f'{lang}wiki'
    if dest.exists():
        print(f"{dest} already exists; not splitting")
        return dest

    dest.mkdir(exist_ok=True, parents=True)
    title_re = re.compile(rf'<doc id="\d+" url="https://{lang}.wikipedia.org/wiki\?curid=\d+" title="([^"]+)">')
    lines = (path/name).open()
    f=None

    for i,l in enumerate(lines):
        if i%100000 == 0: print(i)
        if l.startswith('<doc id="'):
            title = title_re.findall(l)[0].replace('/','_')
            if len(title)>150: continue
            if f: f.close()
            f = (dest/f'{title}.txt').open('w')
        else: f.write(l)
    f.close()
    return dest

# %%
lang = 'hu'
name = f'{lang}wiki'
path = data_path/name
path.mkdir(exist_ok=True, parents=True)
lm_fns = [f'{lang}_wt', f'{lang}_wt_vocab']

# %%
get_wiki(path,lang)
dest = split_wiki(path,lang)
dest.ls()[:5]
# Out:
# /home/jupyter/.fastai/data/huwiki/huwiki already exists; not downloading
# /home/jupyter/.fastai/data/huwiki/docs already exists; not splitting
# [PosixPath('/home/jupyter/.fastai/data/huwiki/docs/Gyorsvonati pótjegy.txt'),
#  PosixPath('/home/jupyter/.fastai/data/huwiki/docs/Orlande de Lassus.txt'),
#  PosixPath('/home/jupyter/.fastai/data/huwiki/docs/Ringelheimi Matilda.txt'),
#  PosixPath('/home/jupyter/.fastai/data/huwiki/docs/Antioxidánsok kapacitása.txt'),
#  PosixPath('/home/jupyter/.fastai/data/huwiki/docs/Bosworthi csata.txt')]

# %%
dest = data_path/"huwiki/docs"
dest.ls()[:5]
# Out:
# [PosixPath('/home/jupyter/.fastai/data/huwiki/docs/Gyorsvonati pótjegy.txt'),
#  PosixPath('/home/jupyter/.fastai/data/huwiki/docs/Orlande de Lassus.txt'),
#  PosixPath('/home/jupyter/.fastai/data/huwiki/docs/Ringelheimi Matilda.txt'),
#  PosixPath('/home/jupyter/.fastai/data/huwiki/docs/Antioxidánsok kapacitása.txt'),
#  PosixPath('/home/jupyter/.fastai/data/huwiki/docs/Bosworthi csata.txt')]

# %%
data = (TextList.from_folder(dest)
                .split_by_rand_pct(0.1, seed=42)
                .label_for_lm()
                .databunch(bs=bs, num_workers=1))

# %%
learn = language_model_learner(data, AWD_LSTM, drop_mult=0.5, pretrained=False)

# %%
doc(language_model_learner)

# %%
lr=1e-4

learn.unfreeze()
learn.fit_one_cycle(1, lr, moms=(0.8,0.7))
learn.save("ulmfit_v2_bme")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.574805</td>
#       <td>2.428606</td>
#       <td>0.557143</td>
#       <td>1:20:15</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.lr_find();
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='99' class='' max='11531', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.86% [99/11531 00:41<1:19:19 5.1783]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
#mdl_path = path/'models'
#mdl_path.mkdir(exist_ok=True)
#learn.save(mdl_path/lm_fns[0], with_opt=False)
#learn.data.vocab.save(mdl_path/(lm_fns[1] + '.pkl'))

# %%
learn.recorder.plot(skip_end=15)

# %%
mdl_path = path/'models'
mdl_path.mkdir(exist_ok=True)
learn.load(mdl_path/lm_fns[0], with_opt=False)
learn.data.vocab.load(mdl_path/(lm_fns[1] + '.pkl'))

# %%
TEXT = "A világ nem más"
N_WORDS = 80
N_SENTENCES = 1

# %%
print("\n".join(learn.predict(TEXT, N_WORDS, temperature=0.75) for _ in range(N_SENTENCES)))
# Out:
# A világ nem más , mint Amerika .
#
#   a város egy , a Föld felszínén élő róka , a róka és a róka . a Róka - hegyen Henry Jackson rendelkezik az első ember , aki egy Mexikó - ellenes első katonai küldetés során a Föld egyik legnagyobb testű részén élt . a legtöbb ember a Földön él , de az Egyesült Államokban egyes fajok a múlt század közepén ( a mai

# %%
learn.freeze()

# %%
learn.load(mdl_path/lm_fns[0], with_opt=False)
# Out:
# LanguageLearner(data=TextLMDataBunch;
#
# Train: LabelList (68 items)
# x: LMTextList
# xxbos xxmaj jules xxmaj verne
#
#   a xxup világ xxup ura
#
#   xxup első xxup fejezet
#
#   xxmaj mi történik a xxmaj kék - hegységben ?
#   xxup második xxup fejezet
#
#   xxmaj morgantonban
#   xxup harmadik xxup fejezet
#
#   a xxmaj nagy xxmaj sasfészek
#   xxup negyedik xxup fejezet
#
#   xxmaj az xxmaj automobil xxmaj klub versenye
#   xxup ötödik xxup fejezet
#
#   xxmaj új - xxmaj anglia partjai körül
#   xxup hatodik xxup fejezet
#
#   xxmaj az első levél
#   xxup hetedik xxup fejezet
#
#   xxmaj harmadszorra
#   xxup nyolcadik xxup fejezet
#
#   xxmaj mindenáron
#   xxup kilencedik xxup fejezet
#
#   a második levél
#   xxup tizedik xxup fejezet
#
#   xxmaj törvényen kívül
#   xxup tizenegyedik xxup fejezet
#
#   xxmaj xxunk
#   xxup tizenkettedik xxup fejezet
#
#   a xxmaj black xxmaj rock - öböl
#   xxup tizenharmadik xxup fejezet
#
#   a xxmaj rém fedélzetén
#   xxup tizennegyedik xxup fejezet
#
#   a xxmaj niagara
#   xxup tizenötödik xxup fejezet
#
#   a xxmaj sasfészek
#   xxup tizenhatodik xxup fejezet
#
#   xxmaj hódító xxmaj robur
#   xxup tizenhetedik xxup fejezet
#
#   a törvény nevében !
#   xxup tizennyolcadik xxup fejezet
#
#   xxmaj az öreg xxmaj xxunk az utolsó szó
#
#
#
#   xxup első xxup fejezet
#
#   xxmaj mi történik a xxmaj kék - hegységben ?
#
#   xxmaj azt a hegyláncot , amely az xxmaj atlanti - óceán amerikai xxunk párhuzamosan
#   húzódik , és xxunk xxmaj észak - xxmaj xxunk , xxmaj xxunk , xxmaj xxunk ,
#   xxmaj xxunk , xxmaj new xxmaj york xxunk , xxmaj allegheny - hegységnek vagy más néven
#   xxmaj appalache - hegységnek hívják . xxmaj két különálló hegylánc alkotja : nyugaton a
#   xxmaj cumberland - hegység , keleten a xxmaj kék - hegység .
#
#   xxmaj bár xxmaj észak - xxmaj amerika keleti részének ez a legjelentősebb xxunk
#   körülbelül kilencszáz mérföld , vagyis xxunk kilométer hosszúságban
#   terül el , átlagos magassága nem haladja meg a hatezer lábat , és legmagasabb
#   csúcsa , a xxmaj washington - csúcs is xxunk méter magas .
#
#   xxmaj ez a hegylánc , amelynek egyik vége az xxmaj alabama folyónál , a másik pedig a
#   xxmaj szent xxmaj lőrinc - folyónál van , nem túlságosan csábítja a xxunk .
#   xxmaj xxunk teteje nem nyúlik fel a légkör magasabb xxunk , így nincs
#   akkora vonzóereje , mint az xxup ó- és xxmaj újvilág fenséges xxunk . xxmaj volt
#   azonban ennek a xxunk egy csúcsa , a xxmaj great xxmaj xxunk , vagyis a xxmaj nagy
#   xxmaj sasfészek , amelyre nem tudtak feljutni , és úgyszólván xxunk
#   látszott .
#
#   xxmaj és bár a hegymászók mind ez ideig nem sok figyelmet szenteltek a xxmaj nagy
#   xxmaj sasfészeknek , ez a hegy mégis rövid idő múlva az érdeklődés középpontjába
#   került , sőt általános nyugtalanságot keltett , és ennek különleges okait már
#   történetünk elején el kell mondanom .
#
#   a saját xxunk csak azért beszélek , mert - mint ez kiderül - én is
#   nagyon belekeveredtem abba a rendkívüli xxunk , amelynél xxunk
#   ritkán lát a huszadik század . xxmaj néha még magam is töprengek rajta , hogy
#   mindez valóban megtörtént - e , és úgy történt - e , ahogy az emlékezetemben -
#   talán helyesebb lenne úgy mondani : a képzeletemben él . xxmaj de mint a
#   washingtoni rendőrség xxunk , akit egyébként rendkívül erős
#   kíváncsiság is hajtott , és aki tizenöt év alatt annyiféle ügyben dolgozott ,
#   és olyan gyakran kapott különösképp kedvére való titkos megbízásokat - nem
#   találtam meglepőnek , amikor xxunk engem küldtek ki e valószínűtlennek
#   tűnő ügy xxunk , amely vizsgálat során annyi xxunk
#   xxunk találtam szemben magam . xxmaj csakhogy már a történet elejétől kezdve
#   feltétlenül xxunk kell nekem . e csodálatos eseményekkel kapcsolatban
#   magamon kívül más xxunk nem xxunk . xxmaj aki nem akar hinni nekem , ám ne
#   higgyen !
#
#   a xxmaj nagy xxmaj sasfészek a festői xxunk xxmaj kék - hegységnek azon a táján van , amely
#   xxmaj észak - xxmaj carolina nyugati részén húzódik . xxmaj gömbölyded alakja meglehetősen
#   tisztán látható a xxmaj sarawba - folyó partján épült xxmaj morganton városka széléről ,
#   vagy még inkább a néhány mérfölddel közelebb eső xxmaj pleasant - xxmaj garden faluból .
#
#   xxmaj lényegében mi is ez a xxmaj nagy xxmaj sasfészek ? xxmaj jogosan nevezik - e így a xxmaj kék-
#   hegységgel szomszédos vidék lakói ? xxmaj mert az természetes , hogy a xxmaj kék-
#   hegységet azért nevezték el így , mivel bizonyos légköri viszonyok mellett
#   körvonalai xxunk játszanak . xxmaj de vajon a xxunk azért nevezték - e
#   xxmaj nagy xxmaj sasfészeknek , mert sasfészek van rajta , ahol ragadozó madarak , sasok ,
#   keselyűk , xxunk fészkelnek ? xxmaj vajon a környék ragadozó madarainak ez
#   a legkedveltebb xxunk ? xxmaj vajon rikoltozó xxunk ott keringenek e
#   fölött a búvóhely fölött , amelyet csak ők xxunk meg ? xxmaj nem , valójában
#   itt sem él több ragadozó madár , mint az xxmaj allegheny - hegység többi csúcsán .
#   xxmaj sőt éppen azt figyelték meg , hogy egyes napokon ezek a madarak , amikor a
#   xxmaj nagy xxmaj sasfészek fölé repülnek , inkább elmenekülni igyekeznek onnan , és egy
#   ideig köröznek felette , majd fülsiketítő xxunk a szélrózsa minden
#   irányában xxunk .
#
#   xxmaj akkor hát miért nevezik xxmaj nagy xxmaj sasfészeknek ? xxmaj nem volna találóbb " xxunk
#   nevezni , mint ahogy ilyen xxunk szerte a világon minden hegyes
#   vidéken találkozunk ? xxmaj mert ott fenn a magas sziklafalak nyilván széles és
#   mély katlant fognak körül , és ki tudja , nincs - e benne egy kis tó vagy
#   xxunk , amelyet az xxunk és télen a hó táplál , hiszen az xxmaj xxunk
#   hegységben különböző xxunk képződtek ilyen tavak , akárcsak az xxup ó- és
#   xxmaj újvilág számos xxunk . xxmaj és nem kellene mostantól kezdve a katlanok
#   között xxunk a földrajzi xxunk ?
#
#   xxmaj végül pedig , hogy valamennyi feltevést megvizsgáljuk , nincs - e ott vajon
#   vulkáni kráter , amely sokáig aludt , és most a belső földlökések
#   felébresztették ? xxmaj vajon nem kell - e a környéken olyan borzalmas xxunk
#   és xxunk tartani , mint a xxmaj xxunk vagy a xxmaj mont xxmaj xxunk környékén ?
#   xxmaj ha pedig azt feltételezzük , hogy xxunk található odafenn , nem kell - e
#   attól félni , hogy a vize xxunk a föld mélyébe , ott a központi tűz gőzzé
#   alakítja , és akkor xxmaj carolina állam xxunk olyan kitöréssel fenyegeti ,
#   amilyen xxunk xxmaj xxunk szigetét sújtotta ? ...
#
#   xxmaj éppen ezt az utóbbi lehetőséget xxunk alá újabban észlelt jelenségek ,
#   ugyanis xxunk tapasztaltak , és ez vulkanikus tevékenységre vall . xxmaj egy
#   alkalommal a földeken dolgozó parasztok még tompa és titokzatos morajt is
#   hallottak .
#
#   xxmaj éjszakánként odafenn xxunk jelentek meg .
#
#   a xxmaj nagy xxmaj sasfészek belsejéből xxunk törtek elő , és amikor a szél ezeket
#   kelet felé hajtotta , korom és hamu hullt belőlük a földre . xxmaj sötét éjszakákon
#   az alacsonyan szálló xxunk visszaverődő sápadt fény baljós világosságot
#   árasztott az egész környékre .
#
#   xxmaj természetes , hogy ezek a különös jelenségek nagyon nyugtalanították a vidék
#   lakosságát . a xxunk járult a parancsoló xxunk :
#   megtudni , mihez tarthatják magukat . a xxmaj carolina államban megjelenő újságok
#   szünet nélkül xxunk " a xxmaj nagy xxmaj sasfészek titkáról " . xxmaj azt tárgyalták , nem
#   veszélyes - e ilyen környéken élni . a cikkek kíváncsiságot , egyszersmind
#   szorongást keltettek - kíváncsiságot azokban , akik a veszélytől nem
#   fenyegetve , csupán a természeti jelenségek iránt érdeklődtek ; és szorongást
#   azokban , akik könnyen xxunk , ha ezek a jelenségek veszéllyel
#   xxunk a környező vidéket . xxmaj ezek közé tartoztak elsősorban xxmaj xxunk
#   xxmaj garden és xxmaj morganton városkák , valamint az xxmaj appalache - hegység lábánál fekvő
#   számos falu és egyszerű tanya lakói .
#
#   xxmaj kétségtelenül sajnálatos , hogy a turisták mind ez ideig nem próbáltak
#   feljutni a xxmaj nagy xxmaj xxunk . xxmaj még soha senki sem xxunk meg a katlant
#   körülvevő sziklafalat , rés pedig talán nincs is rajta , amelyen át a
#   belsejébe lehetne jutni .
#
#   xxmaj és a xxmaj nagy xxmaj sasfészek közelében nincs olyan magasabb pont , xxunk vagy
#   csúcs , ahonnan be lehetne nézni ebbe a katlanba ? xxmaj nincs bizony , több
#   kilométeres körzetben nem akad nála magasabb hegy . a xxmaj xxunk - csúcs , az
#   xxmaj allegheny - hegység egyik legmagasabb pontja meglehetősen távol esik innen .
#
#   a xxmaj nagy xxmaj sasfészek teljes xxunk most már feltétlenül szükségessé vált .
#   a környék lakosságának érdekében meg kellett tudni , nem krátert vesznek - e
#   körül azok a sziklák , és hogy nem fenyegeti - e vulkánkitörés xxmaj carolina
#   államnak ezt a nyugati részét . xxmaj meg kellene tehát xxunk feljutni oda , és
#   megállapítani az észlelt jelenségek okát .
#
#   xxmaj de még mielőtt ezt a nagy nehézségekkel járó expedíciót xxunk
#   volna , olyan alkalom kínálkozott a xxmaj nagy xxmaj sasfészek belsejének felderítésére ,
#   amely a sziklák xxunk is feleslegessé tette .
#
#   xxmaj ez év xxunk első napjaiban xxmaj xxunk léghajós xxunk
#   xxmaj morgantonban készült felszállni . a keleti szél majd a xxmaj nagy xxmaj sasfészek
#   irányába hajtja a léghajót , és minden valószínűsége megvan annak , hogy
#   éppen fölötte repül át . xxmaj és amikor xxmaj xxunk néhány száz lábnyira lesz felette ,
#   nagy erejű xxunk lenéz a mélybe , és xxunk , hogy xxunk
#   keletkezett - e a magas sziklák között . xxmaj mert ez volt a legfontosabb kérdés .
#   xxmaj ha ez kiderül , megtudják , kell - e a környéknek xxunk tartania a
#   közeli vagy távoli jövőben .
#
#   a xxunk az előre meghatározott terv szerint történt . a szél közepes
#   erejű és egyenletes , az ég tiszta volt . a reggeli xxunk éppen
#   eloszlatta az erős napsütés . xxmaj ha a xxmaj nagy xxmaj sasfészek katlanában nem telepedett
#   meg a köd , a léghajós a magasból xxunk az egészet . xxmaj és feltétlenül
#   észre kell vennie , ha a xxunk gőz tör fel . xxmaj ebben az esetben
#   feltételezni kell , hogy a xxmaj kék - hegységnek ezen a pontján vulkán van , és
#   ennek a xxmaj nagy xxmaj sasfészek a krátere .
#
#   a léggömb azonnal ezerötszáz láb magasságig emelkedett , és egy negyedóráig
#   mozdulatlan maradt . xxmaj ebben a magasságban szélcsend volt , a talaj felett
#   pedig erős szél fújt . xxmaj de milyen csalódás következett ! a léggömb nemsokára
#   más xxunk hatása alá került , és kelet felé mozdult el , vagyis éppen
#   távolodott a xxunk , és semmi remény nem volt arra , hogy vissza tudják
#   irányítani . xxmaj nemsokára eltűnt a város lakóinak szeme elől , és csak később
#   tudták meg , hogy xxmaj raleigh környékén szállt le xxmaj észak - xxmaj carolina államban .
#
#   xxmaj miután ez a kísérlet nem sikerült , úgy döntöttek , hogy kedvezőbb
#   körülmények között xxunk . xxmaj újra hallatszottak ugyanis azok a
#   xxunk , amelyeket kormos xxunk és a xxunk visszaverődő , xxunk
#   fény kísért . xxmaj érthető , hogy a környék lakói nem nyugodtak meg , és
#   xxunk vagy xxunk rettegtek .
#
#   xxmaj minden oka megvolt , hogy ez év xxunk első napjaiban az addig többé-
#   kevésbé bizonytalan szorongás xxunk xxunk . a környékbeli lapok
#   állandóan friss xxunk közöltek az általános xxunk . a hegylánc
#   és xxmaj morganton városka között mindenki a közeli katasztrófától rettegett .
#
#   xxmaj április xxunk xxunk virradó éjszaka xxmaj pleasant - xxmaj garden lakói
#   xxunk riadtak fel , amelyet borzalmas dübörgés követett . xxmaj óriási xxunk
#   tört ki a gondolatra , hogy a xxunk ez a része beomlott . xxmaj menekülésre
#   készen rohant ki mindenki a házakból , félve , hogy hatalmas szakadék tátong
#   előttük , amely tíz - tizenöt mérföldnyi körzetben tanyákat és falvakat nyelt
#   el .
#
#   xxmaj az éjszaka koromsötét volt . xxmaj vastag felhők nehezedtek a síkságra . a xxmaj kék-
#   hegység gerince még fényes nappal sem volt látható .
#
#   a sötétben semmit sem lehetett látni , és a mindenfelől xxunk ijedt
#   xxunk senki sem tudta lecsillapítani . xxmaj megrémült férfiak , nők ,
#   gyermekek csoportba verődve próbáltak rátalálni a járható utakra , és a nagy
#   tolongásban egymást lökdösték . xxmaj innen is , onnan is kétségbeesett hangok
#   hallatszottak :
#
#   - xxmaj földrengés ! ...
#
#   - xxmaj kitört a vulkán ! ...
#
#   - xxmaj merre ?
#
#   - a xxmaj nagy xxmaj sasfészekben ...
#
#   xxmaj és gyorsan eljutott a hír egészen xxmaj xxunk , hogy kő , láva és hamu
#   hullott a vidékre .
#
#   xxmaj azt legalább megfigyelhették volna , hogy ha vulkán tör ki , a morajlás
#   xxunk . a xxunk csúcsán lángok xxunk . a fehéren izzó
#   xxunk látni lehetne a sötét éjszakában . xxmaj ez azonban senkinek sem
#   jutott eszébe , és a megrémült emberek azt bizonygatták , hogy otthonukban
#   érezték a xxunk . xxmaj egyébként az is lehetséges volt , hogy ezeket a
#   xxunk a hegylánc oldalából xxunk sziklatömb zuhanása okozta .
#
#   xxmaj most halálos aggodalomban vártak , készen arra , hogy xxmaj pleasant - xxmaj garden vagy
#   xxmaj morganton felé xxunk .
#
#   xxmaj egy óra telt el minden különösebb esemény nélkül . xxmaj csak az xxmaj appalache - hegység
#   hosszú xxunk megtört gyenge nyugati szellő xxunk az alacsonyabban
#   fekvő mocsaras részek sűrűn nőtt xxunk szúrós xxunk .
#
#   xxmaj tehát semmi sem adott okot újabb ijedelemre , és mindenki úgy döntött , hogy
#   hazatér . xxmaj láthatólag már nem kellett tartani semmitől , mégis mindenki úgy
#   érezte , hogy sohasem virrad meg .
#
#   xxmaj nem tartották kétségesnek , hogy xxunk történt , valószínűleg egy óriási
#   sziklatömb vált le a xxmaj nagy xxmaj sasfészek oldaláról . xxmaj könnyen
#   xxunk erről , ha virradatkor néhány mérföldnyi darabon
#   xxunk a hegylánc lábát .
#
#   xxmaj de hajnalban három óra felé ismét riadalom tört ki , mert a sziklafal pereme
#   fölé lángnyelvek csaptak fel . a felhők visszaverték a fényt , és messzire
#   xxunk a környéket . xxmaj ezzel egy időben erős sistergés , ropogás
#   hallatszott .
#
#   xxmaj vajon tűz keletkezett odafenn , és mitől ? xxmaj ezt villámcsapás nem okozhatta ...
#   xxmaj hiszen sehol sem villámlott ... xxmaj meg kell adni , hogy a tűznek bőven akadt
#   tápláléka . xxmaj abban a magasságban az xxmaj allegheny - hegységet éppúgy fák borítják ,
#   mint a xxmaj xxunk vagy a xxmaj kék - hegységet . xxmaj rengeteg fa nő ott , ciprus ,
#   xxunk és örökzöld fák .
#
#   - xxmaj kitört a tűzhányó ! xxmaj kitört a tűzhányó !
#
#   xxmaj mindenfelől ez a kiáltás hallatszott : " xxmaj kitört a tűzhányó ! " a xxmaj nagy xxmaj sasfészek
#   tehát a hegylánc belsejében rejlő vulkán krátere ! xxmaj talán sok évvel vagy
#   éppenséggel több évszázaddal ezelőtt kialudt , és most kezdett ismét
#   működni ? ... xxmaj és vajon a xxunk tüzes xxunk vagy xxunk követi
#   majd ? ... a láva lefelé zúdul - e tüzes patak vagy lavina alakjában , és
#   xxunk mindent , ami elébe kerül , elpusztítja - e az útjában álló xxunk ,
#   falvakat , tanyákat , egyszóval az egész környéket xxunk ,
#   xxunk és xxunk együtt még xxmaj pleasant - xxmaj xxunk és xxmaj xxunk
#   túl is ? ...
#
#   xxmaj most aztán kitört a riadalom , és semmi sem tudta feltartóztatni . a
#   rémülettől őrjöngő asszonyok gyermekeiket maguk után vonszolva vágtak neki
#   a kelet felé vezető utaknak , hogy minél hamarabb messze jussanak a
#   földrengés színhelyétől . xxmaj sok férfi a házakból hordta ki a holmikat ; ami
#   értékesebb volt , xxunk , szabadon bocsátotta a háziállatokat ,
#   lovakat , marhákat , birkákat , és azok minden irányban rémülten futottak
#   szerteszét . xxmaj elképzelhető , micsoda kavarodás támadt , amikor a koromsötét
#   éjszakában ez a rengeteg ember és állat xxunk azon az erdőn , amelyet
#   minden pillanatban xxunk a vulkáni láva , vagy a mocsáron keresztül ,
#   amelynek vize bármikor xxunk ! xxmaj és ha a menekülők frissen keletkezett
#   szakadékba rohannak ? ... xxmaj lesz - e idejük elmenekülni , ha a föld színén
#   hömpölygő , izzó lávafolyam elvágja az útjukat , és lehetetlenné teszi a
#   xxunk ? ...
#
#   a xxunk és megfontoltabb farmerek közül néhányan nem csatlakoztak
#   ehhez a megrémült xxunk , amelyet nem sikerült xxunk .
#
#   xxmaj xxunk indultak , és a hegyláncot körülbelül egymérföldnyire
#   megközelítették , és akkor azt tapasztalták , hogy a lángnyelvek magassága
#   csökkent , és a tűz végül talán ki is alszik . xxmaj minden jel arra mutatott , hogy
#   a vidéket mégsem fenyegeti kitörés . xxmaj nem hullott kőzápor , nem hömpölygött
#   lávafolyam a hegyek lejtőin , nem hallatszott morajlás a föld belsejéből ...
#   xxmaj semmi sem árulkodott olyan xxunk , amely egyetlen szempillantás
#   alatt egész országrészt képes elpusztítani .
#
#   xxmaj ez a megállapítás helyes volt : a xxmaj nagy xxmaj sasfészek belsejében a tűz ereje
#   csökkent . xxmaj lassanként halványodott a felhőkön visszaverődő fény , a környék
#   pedig nemsokára teljes sötétségbe borult , egészen hajnalig .
#
#   a menekülők tolongó tömege pedig csak akkor állt meg , amikor úgy gondolták ,
#   hogy minden veszélytől távol vannak . xxmaj aztán visszajöttek , és néhány falu meg
#   tanya lakói virradatkor már otthon voltak .
#
#   xxmaj négy óra felé a xxmaj nagy xxmaj sasfészek peremén már csak halvány fények látszottak .
#   a tűz lelohadt , nyilván már elégett minden xxunk anyag , és bár a tűz okát
#   még nem lehetett megállapítani , remélhető volt , hogy nem lángol fel ismét .
#
#   xxmaj mindenesetre valószínűnek látszott , hogy a xxmaj nagy xxmaj sasfészekben nem vulkanikus
#   jelenségek játszódtak le . xxmaj ezért nem kellett attól tartani , hogy a környék
#   lakóit vulkánkitörés vagy földrengés fenyegeti .
#
#   xxmaj hajnali öt óra felé azonban a még sötétbe borult xxunk felett furcsa
#   zaj töltötte be a levegőt : szabályos xxunk hangja , amelyet hatalmas
#   xxunk kísértek . xxmaj és ha világos lett volna , a tanyák és falvak lakói
#   hatalmas ragadozó madarat , valamilyen légi szörnyeteget láttak volna
#   xxunk onnan , amely felszállt a xxmaj nagy xxmaj sasfészekből , aztán gyorsan eltűnt
#   keleti irányban .
#
#
#
#
#   xxup második xxup fejezet
#
#   xxmaj morgantonban
#
#   xxmaj washingtonból április 26-án indultam el , és másnap érkeztem meg xxmaj raleigh - be ,
#   xxmaj észak - xxmaj carolina állam székhelyére .
#
#   xxmaj két nappal előbb a rendőrfőnök hívatott irodájába . xxmaj főnököm türelmetlenül
#   várt . xxmaj most elmondom , miről beszélgettünk , és ebből kiderül xxunk
#   célja is .
#
#   - xxmaj john xxmaj strock - kezdte - , ön még mindig az az éles elméjű és szolgálatkész
#   rendőrtiszt , aki már néhányszor bebizonyította xxunk és
#   éleselméjűségét ?
#
#   - xxmaj ward úr - feleltem meghajolva - , nem az én dolgom megállapítani , hogy
#   bármit is csökkent - e xxunk ... xxmaj ami viszont xxunk illeti ,
#   kijelenthetem , hogy teljes mértékben ...
#
#   - xxmaj ebben nem kételkedem - folytatta xxmaj ward úr - , csak pontosabban xxunk
#   meg a kérdést : még mindig olyan kíváncsi természetű ember - e , olyan lelkesen
#   fog - e hozzá egy rejtély xxunk , mint eddig ?
#
#   - xxmaj még mindig , xxmaj ward úr .
#
#   - xxmaj és a kíváncsiság ösztöne nem gyengült meg az állandó munkája során ?
#
#   - xxmaj egy cseppet sem !
#
#   - xxmaj akkor , xxmaj strock , figyeljen !
#
#   xxmaj ward úr akkoriban ötvenéves , szellemi ereje teljében levő férfi volt , és
#   fontos munkáját nagyszerűen értette . xxmaj többször bízott rám nehéz ügyeket ,
#   amelyeket sikerrel oldottam meg , sőt politikai xxunk is , és ezek
#   xxunk elismerését fejezte ki . xxmaj néhány hónap óta azonban egyetlen
#   alkalommal sem vette igénybe szolgálataimat , és ezt a xxunk nagyon
#   keservesen viseltem el . xxmaj ezért vártam türelmetlenül , mit akar velem közölni
#   xxmaj ward úr . xxmaj nem kételkedtem , hogy komoly ok miatt akar engem bevonni ebbe a
#   munkába .
#
#   xxmaj az az ügy , amelyet a rendőrfőnök számomra tartogatott , nemcsak xxmaj észak-
#   xxmaj carolinában és a szomszédos államokban , hanem egész xxmaj amerikában
#   foglalkoztatta a közvéleményt .
#
#   - xxmaj bizonyára értesült róla - mondta - , hogy mi történik az xxmaj appalache - hegység
#   egyik részében , xxmaj morganton városka környékén .
#
#   - xxmaj igen , xxmaj ward úr , és véleményem szerint ezek a meglehetősen furcsa
#   jelenségek igen alkalmasak arra , hogy xxunk a nálam kevésbé kíváncsi
#   emberek kíváncsiságát is .
#
#   - xxmaj semmi kétség , xxmaj strock , hogy ez az egész ügy furcsa , sőt különös . xxmaj de nem
#   árt azon gondolkozni , hogy a xxmaj nagy xxmaj sasfészekben megfigyelt jelenségek nem
#   jelentenek - e veszélyt a környék xxunk ; vajon ezek nem vulkánkitörés
#   vagy földrengés előjelei - e ...
#
#   - xxmaj bizony , ettől tartanunk kell , xxmaj ward úr .
#
#   - xxmaj akkor pedig meg kell tudnunk , xxmaj strock , hogy hányadán állunk . xxmaj ha egy
#   esetleg bekövetkező természeti csapás ellen nem is tehetünk semmit , az
#   xxunk mégis idejében figyelmeztetni kellene , hogy milyen veszély
#   fenyegeti őket .
#
#   - xxmaj ez a hatóságok feladata , xxmaj ward úr - feleltem . - xxmaj pontosan kellene tudnunk ,
#   hogy mi történik ott fenn .
#
#   - xxmaj helyes , xxmaj strock , de úgy látszik , ez súlyos nehézségekbe ütközik . a
#   környékbeliek előszeretettel hajtogatják , hogy a xxmaj nagy xxmaj sasfészek szikláit
#   nem lehet megmászni , nem lehet bejutni a belsejébe . xxmaj de xxunk - e
#   egyáltalán vele , és ráadásul olyan körülmények között , amely a sikert
#   biztosíthatta volna ? ... xxmaj nem hiszem , pedig úgy gondolom , hogy alaposan
#   előkészített kísérlet feltétlenül sikerre vezet .
#
#   - xxmaj semmi sem lehetetlen , xxmaj ward úr , és ez minden bizonnyal csak költség
#   kérdése .
#
#   - xxmaj indokolt xxunk , xxmaj strock , és nem lehetünk tekintettel a költségekre ,
#   amikor a lakosságot kell megnyugtatni vagy figyelmeztetni , hogy egy
#   katasztrófától xxunk . xxmaj egyébként a xxmaj nagy xxmaj sasfészek valóban olyan
#   megközelíthetetlen , mint állítják ? xxmaj és ki tudja , nem ott rendezte - e be
#   búvóhelyét valamilyen xxunk , amely az oda vezető utat egyedül
#   ismeri ? ...
#
#   - xxmaj hogyan ? ! xxmaj ward úr azt gyanítja , hogy rablók ...
#
#   - xxmaj lehet , hogy tévedek , xxmaj strock , és minden , ami ott fenn történik , természeti
#   xxunk vezethető vissza ... xxmaj éppen ezt kell xxunk , éspedig a lehető
#   legrövidebb időn belül .
#
#   - xxmaj xxunk valamit , xxmaj ward úr ?
#
#   - xxmaj rajta , xxmaj strock .
#
#   - xxmaj ha xxunk a xxmaj nagy xxmaj sasfészekbe , ha xxunk ezeknek a jelenségeknek
#   az okait , ha ott fenn krátert találunk , ha a vulkán kitörése hamarosan
#   várható , ezt meg tudjuk akadályozni ?
#
#   - xxmaj nem , xxmaj strock , de figyelmeztetni tudjuk a környék lakosait . xxmaj akkor a
#   falvakban tudják , mihez tartsák magukat , és a tanyákon élőket sem éri
#   meglepetés . xxmaj ki tudja , hogy az xxmaj allegheny - hegység xxunk nem fenyegeti - e
#   xxmaj észak - xxmaj xxunk olyan pusztulással , mint xxmaj xxunk szigetét a xxmaj mont xxmaj xxunk
#   xxunk ? ... xxmaj legalább annyit kell xxunk , hogy a lakosság biztonságba
#   tudja magát helyezni .
#
#   - xxmaj szeretném hinni , xxmaj ward úr , hogy nem fenyegeti ilyen veszély azt a
#   környéket ...
#
#   - xxmaj én is ezt kívánom , xxmaj strock , egyébként is valószínűtlennek tűnik , hogy a
#   xxmaj kék - hegységnek ezen a részén tűzhányó lenne . xxmaj az xxmaj appalache - hegylánc nem
#   vulkanikus eredetű . a hozzánk befutott jelentések szerint látták , hogy
#   lángok törnek elő a xxmaj nagy xxmaj sasfészekből ... xxmaj még xxmaj pleasant - xxmaj garden környékén is
#   úgy vélték , hogy ha nem is xxunk , de xxunk éreztek . xxmaj vajon
#   igaz - e mindez , vagy csak képzelődés ? xxmaj ezt kell megállapítanunk .
#
#   - xxmaj ez a legokosabb dolog , xxmaj ward úr , és talán késedelem nélkül ...
#
#   - xxmaj ezért elhatároztuk , xxmaj strock , hogy vizsgálatot xxunk a xxmaj nagy xxmaj sasfészekben
#   lejátszódott xxunk kapcsolatban . xxmaj valaki minél előbb oda utazik ,
#   hogy xxunk az összes adatot , kihallgassa a városkák és tanyák
#   lakóit . xxmaj ennek elvégzésére olyan xxunk választottunk , akiben teljes
#   mértékben megbízunk , és ez a felügyelő ön , xxmaj strock ...
#
#   - xxmaj nagyon örülök , xxmaj ward úr - feleltem - és számíthat rám ; semmit el nem
#   xxunk , hogy teljes megelégedését xxunk .
#
#   - xxmaj tudom , xxmaj strock , és hozzáteszem , hogy ez bizonyára kedvére való feladat ...
#
#   - xxmaj feltétlenül , xxmaj ward úr .
#
#   - a maga szenvedélyes kíváncsisága itt állandóan xxunk , és remélem , ki
#   is xxunk ...
#
#   - xxmaj úgy van .
#
#   - xxmaj egyébként saját belátása szerint jár el , ahogy a körülmények megkívánják .
#   xxmaj ha pedig a xxunk xxunk sokba kerülne , a xxunk nem
#   xxunk meg a kezét ...
#
#   - xxmaj ami tőlem telik , mindent megteszek , xxmaj ward úr , számíthat rám .
#
#   - xxmaj azt ajánlom , xxmaj strock , hogy xxunk során a xxunk xxunk
#   mindent ... xxmaj ott a kedélyek még túl izgatottak . xxmaj nagyon erős fenntartással
#   kell fogadnia mindent , amit xxunk , és vigyázzon , hogy a vizsgálat ne
#   okozzon újabb riadalmat .
#
#   - xxmaj értem .
#
#   - a morgantoni polgármester mellé rendeltem , ő mindig magával egyetértésben
#   jár el . xxmaj ismétlem , legyen óvatos , xxmaj strock , és a xxunk csak azokat a
#   személyeket vonja be , akikre feltétlenül szüksége van . xxmaj xxunk és
#   ügyességét már sokszor bebizonyította , és most is számítunk arra , hogy
#   sikerrel jár ...
#
#   - xxmaj ha nem járok sikerrel , xxmaj ward úr , csak az lehet az oka , hogy legyőzhetetlen
#   akadályokba ütközöm , mert végeredményben lehetséges , hogy nem sikerül
#   xxunk a xxmaj nagy xxmaj sasfészekbe , és ebben az esetben ...
#
#   - xxmaj ebben az esetben majd meglátjuk , mi a teendő . xxmaj ismétlem , tudjuk , hogy
#   xxunk és xxunk fogva nincs magánál xxunk ember , és ez
#   kitűnő alkalom arra , hogy kíváncsiságát kielégítse .
#
#   xxmaj ward úr igazat mondott .
#
#   xxmaj akkor megkérdeztem tőle :
#
#   - xxmaj mikor kell indulnom ?
#
#   - xxmaj már holnap .
#
#   - xxmaj holnap tehát elindulok xxmaj washingtonból , holnapután pedig xxmaj morgantonban
#   leszek .
#
#   - xxmaj levélben vagy távirati úton állandóan xxunk ...
#
#   - xxmaj minden rendben lesz , xxmaj ward úr . xxmaj amikor elbúcsúzom , még egyszer xxunk ,
#   hogy engem választott a xxmaj nagy xxmaj sasfészek - ügy xxunk vezetésére .
#
#   xxmaj hogy is sejthettem volna , mit tartogat számomra a jövő ? !
#
#   xxmaj tüstént hazamentem , xxunk , és másnap hajnalban a gyorsvonat
#   xxmaj észak - xxmaj carolina fővárosa felé robogott velem .
#
#   xxmaj aznap este megérkeztem xxmaj raleigh - be , az éjszakát ott töltöttem , és másnap
#   délután az állam nyugati részébe vezető vonattal xxmaj xxunk érkeztem .
#
#   xxmaj morganton tulajdonképpen csak kis mezőváros . xxmaj xxunk igen gazdag ,
#   xxunk vastag xxunk épült , a xxunk igen élénk xxunk folyik . xxmaj bő
#   xxunk fakadnak itt , nyáron sokan járnak ide xxunk .
#   xxmaj morganton környékének fejlett a xxunk , és a xxunk gazdag
#   termést xxunk be a xxunk és náddal benőtt mocsarak között
#   fekvő xxunk .
#
#   xxmaj sok azon a tájon az örökzöld erdő . xxmaj nincs azonban a környéken xxunk , az a
#   kimeríthetetlen xxunk , amelyet világításra és fűtésre is
#   xxunk , és amelyben az xxmaj allegheny - hegység legtöbb völgye oly
#   gazdag .
#
#   a talaj összetétele és bő xxunk következtében sok ember lakik a
#   környéken . xxmaj falvak és tanyák sorakoznak egymás után egészen az xxmaj xxunk
#   hegység lábáig ; itt , az erdők között sűrűbben , ott , a hegyek első
#   xxunk pedig már ritkábban .
#
#   xxmaj errefelé több ezer embert xxunk veszély , ha a xxmaj nagy xxmaj sasfészek
#   xxunk lenne , ha a kitörése xxunk és hamuval borítaná be a
#   környéket , ha lávafolyamok xxunk el a földeket , ha a földrengés
#   xxunk xxmaj pleasant - xxmaj xxunk és xxmaj xxunk xxunk .
#
#   xxmaj morganton polgármestere , xxmaj elias xxmaj smith magas , jó erőben levő , bátor ,
#   vállalkozó kedvű férfi volt , még nem töltötte be a negyvenedik xxunk ;
#   xxunk a két xxmaj amerika valamennyi orvosa sem találna xxunk ,
#   a tél hidegét és a nyár melegét egyaránt jól bírta , mert az időjárás xxmaj észak-
#   xxmaj carolinában néha igen szélsőséges . xxmaj olyan nagy vadász volt , hogy nemcsak az
#   xxmaj appalache - hegységgel szomszédos síkságon nagy számban előforduló xxunk és
#   xxunk vadászott , hanem medvére és xxunk is , melyek bőven
#   találhatók mind a sűrű xxunk , mind pedig az xxmaj allegheny - hegység
#   kettős xxunk vad xxunk .
#
#   xxmaj elias xxmaj smith gazdag földbirtokos volt , néhány tanyája is feküdt xxmaj morganton
#   környékén . xxmaj több tanyán személyesen vezette a gazdaságot . xxmaj xxunk gyakran
#   meglátogatta , és amikor nem tartózkodott városi otthonában , minden idejét
#   xxunk és vadászattal töltötte , olyan ellenállhatatlanul vonzotta
#   xxunk .
#
#   xxmaj délután azt kértem , hogy vezessenek el xxmaj elias xxmaj smith házába . xxmaj aznap otthon
#   tartózkodott , mivel távirati úton értesítették xxunk . xxmaj átadtam neki
#   xxmaj ward úr xxunk , amelyben közli , hogy melléje rendelt , és
#   ismeretséget kötöttünk egymással .
#
#   xxmaj morganton polgármestere pipával a szájában , xxunk pohárral az asztalon
#   szívélyesen , fesztelenül fogadott . xxmaj egy xxunk mindjárt hozott poharat
#   nekem is , és mielőtt belefogtunk volna a beszélgetésbe , meg kellett
#   felelnem házigazdám xxunk .
#
#   - xxmaj önt xxmaj ward úr küldte - mondta vidáman - , hát akkor igyunk először is xxmaj ward
#   úr egészségére !
#
#   xxmaj xxunk kellett , és poharunkat a rendőrség xxunk
#   egészségére xxunk .
#
#   - xxmaj és most lássuk : miről van szó ? - kérdezte xxmaj elias xxmaj smith .
#
#   xxmaj erre elmondtam xxmaj morganton xxunk , miért küldtek xxmaj észak - xxmaj xxunk
#   erre a vidékére . xxmaj emlékezetébe idéztem azokat a tényeket , helyesebben :
#   jelenségeket , amelyeket ezen a vidéken tapasztaltak . xxmaj megjegyeztem , mennyire
#   fontos , hogy a környék lakóit xxunk , vagy legalábbis xxunk
#   xxunk , és ebben egyetértett velem . xxmaj közöltem vele , hogy a hatóságok
#   beavatkozása igen indokolt ; hogy amennyire hatalmukban áll , xxunk az
#   itteni helyzetet . a főnököm teljhatalmat adott - tettem hozzá végül - , hogy
#   minél gyorsabban és xxunk vezessem a nyomozást a xxmaj nagy
#   xxmaj xxunk kapcsolatban . xxmaj nem szabad xxunk semmilyen xxunk ,
#   semmilyen xxunk , hiszen küldetésem minden költségét természetesen a
#   minisztérium viseli .
#
#   xxmaj elias xxmaj smith szótlanul végighallgatott , közben azonban többször xxunk
#   xxunk . xxmaj miközben pipájából jóízűen eregette a xxunk , láttam
#   rajta , hogy erősen figyel . xxmaj arca gyakran felélénkült , szeme pedig tüzelt
#   sűrű szemöldöke alatt . xxmaj morganton első xxunk szemlátomást
#   nyugtalanították a xxmaj nagy xxmaj sasfészekben lejátszódó események , és hozzám
#   hasonlóan ő is türelmetlenül várta , hogy kiderüljön a jelenségek valódi
#   oka .
#
#   xxmaj amikor végeztem , xxmaj elias xxmaj smith rám nézett , és néhány pillanatig szótlan
#   maradt .
#
#   - xxmaj tehát xxmaj washingtonban szörnyen kíváncsiak - mondta végül - , mi van a xxmaj nagy
#   xxmaj sasfészek gyomrában ?
#
#   - xxmaj igen , xxmaj smith úr ...
#
#   - xxmaj és ön is ?
#
#   - xxmaj nagyon !
#
#   - xxmaj magam is , xxmaj strock úr !
#
#   xxmaj hát ha xxmaj morganton polgármestere éppolyan kíváncsi fajta , mint jómagam , akkor
#   pompásan xxunk !
#
#   - xxmaj megérti - tette hozzá kiverve pipájából a hamut - , mint földbirtokost ,
#   nagyon érdekel , mi történik a xxmaj nagy xxmaj sasfészekben , és mint xxunk ,
#   törődnöm kell xxunk lakosainak helyzetével .
#
#   - xxmaj így hát , xxmaj smith úr - válaszoltam - , önt két ok is vezeti , hogy keresse
#   azoknak a jelenségeknek az okát , amelyek az egész környéket fenyegetik ! xxmaj és
#   ezeket a jelenségeket nyilván megmagyarázhatatlannak találta , egyszersmind
#   xxunk a környék xxunk nézve ...
#
#   - xxmaj főleg megmagyarázhatatlannak találtam , xxmaj strock úr , mert én alig hiszem ,
#   hogy a xxmaj nagy xxmaj sasfészek kráter , hisz az xxmaj allegheny - hegység nem vulkanikus
#   jellegű . xxmaj sehol sem bukkantak hamu , xxunk , láva vagy más vulkanikus eredetű
#   anyag nyomára , sem a xxmaj cumberland - hegység xxunk , sem a xxmaj kék - hegység
#   xxunk . xxmaj éppen ezért nem gondolom , hogy xxmaj morganton környékét ilyen nagy
#   veszély xxunk .
#
#   - xxmaj igazán így gondolja , xxmaj smith úr ?
#
#   - xxmaj igazán .
#
#   - xxmaj mégis , azok a földlökések , amelyeket a hegylánc közelében éreztek ? ...
#
#   - xxmaj igen , azok a földlökések ... azok a földlökések ... - ismételte a fejét
#   csóválva xxmaj smith úr . - xxmaj először is biztos , hogy azok földlökések voltak ? xxmaj mikor
#   azok a nagy xxunk xxunk , éppen a wildoni xxunk voltam , nem
#   egészen egymérföldnyire a xxmaj nagy xxmaj xxunk , és ha valami xxunk
#   tapasztaltam is a levegőben , nem éreztem sem a föld xxunk , sem a
#   belsejéből eredő xxunk .
#
#   - xxmaj pedig a xxmaj ward úrnak küldött jelentések szerint ...
#
#   - xxmaj azokat a jelentéseket a rémület hatása alatt írták ! - jelentette ki a
#   morgantoni polgármester . - xxmaj az én xxunk mindenesetre szó sem esett
#   ilyesmiről .
#
#   - xxmaj ez figyelemre méltó . xxmaj ami azonban a csúcs fölé csapó lángokat illeti ...
#
#   - xxmaj hát a xxunk , xxmaj strock úr , egészen más a helyzet ! xxmaj azokat én is láttam ...
#   saját szememmel , és a felhők úgy verték vissza a fényüket , hogy messze
#   földről is látni lehetett . xxmaj meg aztán valami zaj is hallatszott a xxmaj nagy
#   xxmaj sasfészek csúcsáról ... xxunk hasonló hang , mint amikor a xxunk
#   xxunk a gőzt .
#
#   - xxmaj és ezt ön is hallotta ?
#
#   - xxmaj igen ... majdnem xxunk !
#
#   - xxmaj és nem tűnt úgy önnek , mintha óriási xxunk hangja vegyült volna
#   ebbe a xxunk ?
#
#   - xxmaj de igen , xxmaj strock úr . xxmaj csakhogy a xxunk hangjából ítélve , milyen
#   óriási madárnak kellett volna xxunk az utolsó lángok xxunk
#   után ? ... xxmaj és mekkora lehet az ilyennek a szárnya ? xxmaj nem tudom , nem a képzelet
#   játszott - e velem ! a xxmaj nagy xxmaj sasfészek légi szörnyetegek fészke volna ? xxmaj és nem
#   vették észre már régen azokat a szörnyeket , amint hatalmas xxunk
#   felett köröznek ? xxmaj itt valóban van valami rejtély , amit eddig nem sikerült
#   felderíteni ...
#
#   - xxmaj de most xxunk , xxmaj smith úr , ha hajlandó segíteni nekem .
#
#   - xxmaj természetesen , xxmaj strock úr , annál is inkább , mivel nagyon fontos , hogy a
#   környék lakóit xxunk .
#
#   - xxmaj akkor hát holnap elkezdjük ...
#
#   - xxmaj úgy van , holnap !
#
#   xxmaj ezekkel a szavakkal váltunk el egymástól .
#
#   xxmaj visszamentem a szállodába , és közöltem , hogy annyi időre veszem ki a
#   szobát , amennyit a nyomozás megkíván .
#
#   xxmaj azonnal levelet írtam xxmaj ward úrnak . xxmaj értesítettem , hogy megérkeztem
#   xxmaj xxunk , közöltem vele , milyen eredménnyel zárult első xxunk a
#   városka xxunk , és hogy elhatároztuk , mindent megteszünk , hogy a
#   nyomozás a legrövidebb időn belül sikerrel végződjék . xxmaj azt is megígértem ,
#   hogy minden xxunk beszámolok neki akár levélben , akár
#   xxunk , s állandóan értesítem , milyen a xxunk xxmaj carolina államnak
#   ezen a részén .
#
#   xxmaj smith úrral aznap délután még egyszer xxunk , és elhatároztuk , hogy
#   mihelyt megvirrad , elindulunk .
#
#   xxmaj végül a következő terv mellett döntöttünk :
#
#   xxmaj két , xxunk jártas xxunk xxunk , hogy xxunk a
#   hegyre . xxmaj vezetőink már többször xxunk a xxmaj kék - hegység legmagasabb
#   csúcsait . xxmaj igaz , a xxmaj nagy xxmaj xxunk még soha nem próbálkoztak , mert tudták ,
#   hogy megmászhatatlan xxunk nem tudnak átjutni , másrészt pedig mert
#   amíg ezeket a jelenségeket nem tapasztalták , a turisták alig érdeklődtek a
#   xxmaj nagy xxmaj sasfészek iránt . a két xxunk egyébként számíthatunk , xxmaj smith úr maga
#   is vakmerő , ügyes és mindenre kész embernek ismerte őket . xxmaj nem hátrálnak meg
#   az akadályok előtt , ha mi hajlandók vagyunk követni őket .
#
#   xxmaj smith úr megjegyezte , hogy ráadásul most már talán nem is lesz lehetetlen
#   bejutni a xxmaj nagy xxmaj sasfészek belsejébe .
#
#   - xxmaj és miért ? - kérdeztem .
#
#   - xxmaj mert a sziklatömb néhány héttel ezelőtt levált a hegyről , és így talán
#   van járható út .
#
#   - xxmaj az nagyon szerencsés véletlen lenne , xxmaj smith úr .
#
#   - xxmaj megtudjuk , xxmaj strock úr , mégpedig holnap ...
#
#   - xxmaj tehát a holnapi viszontlátásra !
#
#
#
#
#   xxup harmadik xxup fejezet
#
#   a xxmaj nagy xxmaj sasfészek
#
#   xxmaj másnap hajnalban xxmaj elias xxmaj xxunk elindultam xxmaj morgantonból azon az úton ,
#   amely a xxmaj sarawba - folyó bal partján xxmaj pleasant - xxmaj garden városába vezet .
#
#   a vezetők is csatlakoztak hozzánk - a harmincéves xxmaj harry xxmaj horn és a huszonöt
#   éves xxmaj james xxmaj bruck , mindketten a város lakosai , akik az xxmaj allegheny - hegység
#   kettős láncát alkotó xxmaj kék - hegység és xxmaj cumberland - hegység magasabb xxunk
#   szokták vezetni a xxunk . xxmaj elszánt , ügyes és tapasztalt hegymászók ,
#   karjuk és lábuk erős , a xxunk nyúló vidéket kitűnően ismerik .
#
#   xxmaj két jó ló húzta a xxunk , amellyel xxmaj carolina állam nyugati széléig
#   xxunk menni . a kocsin csak két - három napi élelmet vittünk , mert
#   felderítő utunk nyilván nem tart hosszabb ideig . xxmaj az élelmiszerek
#   xxunk xxmaj smith úrra bíztam ; az xxunk között volt xxunk ,
#   sonka , xxunk sült xxunk , egy kis hordó sör , néhány üveg whisky és
#   pálinka , valamint megfelelő mennyiségű kenyér . xxmaj ivóvizet találunk a sok
#   hegyi forrásban , amelyeket az xxunk gyakori záporok bőven táplálnak .
#
#   xxmaj felesleges is mondanom , hogy a morgantoni polgármester , a szenvedélyes
#   vadász , magával hozta puskáját és kutyáját , xxmaj xxunk is , amely állandóan a
#   kocsi mellett xxunk és ugrándozott . xxmaj xxunk xxunk a vadat , amíg az
#   erdőben vagy a síkságon leszünk , de amíg a hegyet xxunk , a kocsissal
#   együtt a wildoni tanyán marad . a xxmaj nagy xxmaj xxunk nem jöhet velünk , mert
#   nagy szakadékokon kell átkelnünk , és magas sziklákat kell xxunk .
#
#   xxmaj az égbolt meglehetősen tiszta volt , a levegő még hűvös , mert április vége
#   felé az amerikai éghajlat alatt még gyakran igen zord az idő .
#
#   xxmaj az xxmaj atlanti - óceán nagy kiterjedésű xxunk változó irányú szél fújt , és
#   gyors felhőket sodort , közöttük fel - xxunk a nap , és beragyogta az egész
#   környéket .
#
#   xxmaj már az első nap elérkeztünk xxmaj pleasant - xxmaj xxunk , az éjszakát ott töltöttük a
#   városka xxunk , xxmaj smith úr régi jó xxunk . xxmaj kíváncsian figyeltem
#   a környéket , ahol a mocsár után szántóföld , majd a xxunk után ismét
#   mocsár tárul az utazó szeme elé . a jól xxunk út hol áthalad ezeken ,
#   hol mellettük vezet el , közben pedig alig kanyarog . xxmaj az enyhén mocsaras
#   részeken csodálatos magas és egyenes törzsű xxunk emelkednek , az alsó
#   részük kissé xxunk , és tele van apró xxunk , mintha xxunk nőttek
#   volna rajtuk , a környéken ezekből készítik a xxunk . a xxunk
#   xxunk xxunk szél hosszú , szürke xxunk xxunk , amelyet itt " spanyol
#   xxunk neveznek , és amely az alacsonyabb ágakról egészen a földig
#   csüng .
#
#   a környék xxunk igen sokféle állat található . xxmaj kocsink előtt egerek ,
#   xxunk , rikító tollú és rikácsoló hangú papagájok , aprókat xxunk ,
#   kicsinyeiket xxunk xxunk xxunk riadtak fel ; megszámlálhatatlan
#   sok madár rebbent fel az indiai xxunk , xxunk , xxunk lombjai
#   közül , amelyeknek rügyei az első tavaszi fuvallatra xxunk , továbbá a
#   sűrű xxunk közé , amelyeken néhol még gyalogosan sem lehet
#   átvergődni .
#
#   xxmaj este megérkeztünk xxmaj pleasant - xxmaj xxunk , ahol megfelelő helyet találtunk
#   éjszakára . a következő nap kényelmesen el tudunk jutni a wildoni tanyára , a
#   hegylánc lábához .
#
#   xxmaj pleasant - xxmaj garden közepes nagyságú mezőváros . a polgármester szívélyesen
#   fogadott , és derekasan ellátott minket . a hatalmas bükkfák alatt meghúzódó ,
#   takaros házának xxunk kedélyes hangulatban xxunk el a
#   vacsorát . xxmaj természetesen arról az xxunk beszéltünk , amelynek során a
#   xxmaj nagy xxmaj sasfészek belsejét akartuk felderíteni .
#   - xxmaj igazuk van - mondta a házigazdánk . - xxmaj amíg a környék lakói nem tudják , mi
#   történik odafent , vagy hogy ki rejtőzködik ott , nem nyugszanak meg ...
#   - xxmaj de nem történt azóta semmi - kérdeztem - , amióta lángokat láttak a xxmaj nagy
#   xxmaj sasfészek fölött ?
#   - xxmaj semmi , xxmaj strock úr . xxmaj pleasant - xxmaj xxunk könnyű szemmel tartani végig a
#   xxunk egészen xxmaj black xxmaj dome - ig , a legmagasabb pontig . xxmaj semmi gyanús
#   hangot nem hallottunk , semmi fényt sem láttunk . xxmaj és ha egy egész csapat
#   ördög fészkelte is be oda magát , xxunk már nem működik , és
#   elvonultak az xxmaj allegheny - hegység egy más xxunk .
#   - xxmaj ördögök ! - kiáltott fel xxmaj smith úr . - xxmaj szeretném én azt látni , hogy úgy
#   mentek el , hogy nem maradt utánuk semmi nyom , a farkuk vége vagy a szarvuk
#   hegye ! xxmaj majd meglátjuk !
#   xxmaj másnap , 29-én a kocsi már virradatkor várt ránk . xxmaj smith úr ismét elfoglalta
#   a helyét , én is az enyémet . a kocsis a lovak közé csapott , és azok
#   nekiiramodtak . xxmaj két napja hogy elindultunk xxmaj morgantonból , és a második nap
#   estéjén már a wildoni tanyán leszünk , a xxmaj kék - hegység első nyúlványai között .
#   a vidék külseje semmit sem változott . xxmaj továbbra is erdők váltakoztak
#   mocsaras xxunk , de a mocsarak ritkultak , ahogy a xxunk közelebb
#   érve a talaj szintje egyre magasabb lett . xxmaj ez a környék már ritkábban
#   lakott . xxmaj csak néhol bújt meg egy - egy falu a bükkfák hatalmas lombkoronája
#   alatt vagy néhány magányos tanya a sok xxunk lezúduló folyócska
#   mentén , amelyek mind a xxmaj sarawba - folyóba ömlenek .
#   xxmaj az állatvilág és a növényvilág ugyanaz volt , mint az előző nap , és annyi
#   vad itt is akadt , hogy a vadásznak sikeres zsákmányt xxunk .
#   - xxmaj igazán kísértést érzek , hogy puskát xxunk , és xxunk xxmaj xxunk ! -
#   mondta xxmaj smith úr . - xxmaj most járok erre először úgy , hogy nem xxunk oda egy
#   marék sörétet a foglyok és nyulak közé ! xxmaj ezek a jámbor állatok rám sem
#   ismernek ! xxmaj de amíg az xxunk el nem fogy , mással kell törődnünk :
#   xxunk vadászunk ...
#   - xxmaj és nem xxunk vissza üres xxunk , xxmaj smith úr ! - tettem hozzá .
#   xxmaj délelőtt óriási síkságon vezetett át az utunk , ahol a xxunk és
#   xxunk csak kisebb xxunk , xxunk alkottak . xxmaj ameddig a szem
#   ellátott , mindenfelé szeszélyes formájú kis xxunk lehetett látni ,
#   amelyekben egész sereg apró rágcsáló nyüzsgött . xxmaj ezrével élt itt csoportosan
#   az a xxunk , amelyet xxmaj amerikában közönségesen csak xxunk hívnak .
#   xxmaj nem azért nevezték el így ezt az xxunk , mintha bármiben is hasonlítana
#   valamelyik xxunk . xxmaj nem , csupán azért , mert éppen úgy xxunk , mint
#   a xxunk . xxmaj valóban , amíg közöttük haladtunk át , be kellett xxunk a
#   fülünket .
#   xxmaj az xxmaj egyesült xxmaj államokban nem számít ritka alkalomnak , ha ilyen népes
#   xxunk bukkan az ember . a xxunk ezek között említik
#   meg xxmaj xxunk - t , vagyis xxmaj xxunk , amelyet igen találóan neveztek el így ,
#   mert xxunk több négylábú lakosa van .
#   xxmaj ezek a mókusok xxunk , füvön és xxunk élnek , ez utóbbit különösen
#   kedvelik ; egyébként ártalmatlan állatok , csak úgy üvöltenek , hogy az ember
#   xxunk tőle .
#   xxmaj az idő szép maradt , de hideg szél fújt . xxmaj mert azt ne higgyük , hogy a 35 .
#   szélességi fok alatt a két xxmaj carolina államnak aránylag meleg az éghajlata .
#   xxmaj errefelé gyakori a nagyon hideg tél . a hideg miatt rengeteg xxunk
#   pusztul ki , és az is előfordul , hogy a xxmaj sarawba medrét jégtorlasz zárja el .
#   xxmaj délután a látóhatár egy részén feltűnt előttünk a xxmaj kék - hegység vonulata , már
#   csak hat mérföldre voltunk tőle . xxmaj gerince élesen rajzolódott ki a
#   meglehetősen tiszta égbolton , amelyen csak néhány xxunk úszott . a
#   hegy lábánál igen sűrű xxunk erdő nőtt , a fák ágai egymásba gabalyodtak ;
#   néhány fa élesen kivált a különleges alakú , feketés sziklák előtt . xxmaj itt is ,
#   ott is érdekes alakú xxunk emelkedtek , xxunk nyúlt közülük
#   a jobb kéz felől eső xxmaj black xxmaj dome a maga xxunk méteres xxunk , és néha
#   vakítóan szikrázott a napsütésben .
#
#   - xxmaj ön xxunk már ezt a csúcsot , xxmaj smith úr ? - kérdeztem .
#
#   - xxmaj nem - felelte - , de azt mondják , meglehetősen nehéz feljutni rá .
#   xxmaj egyébként néhány turista már felkapaszkodott egészén a tetejéig , és azt
#   mondják , a csúcsáról sem lehet belátni a xxmaj nagy xxmaj sasfészek belsejébe .
#
#   - xxmaj úgy bizony - erősítette meg xxmaj harry xxmaj horn , egyik vezetőnk - , én magam is így
#   tapasztaltam .
#
#   - xxmaj talán az idő nem volt kedvező - jegyeztem meg .
#
#   - xxmaj ellenkezőleg , nagyon is tiszta volt , xxmaj strock úr , a xxmaj nagy xxmaj sasfészek pereme
#   azonban olyan magas , hogy attól nem lehet belátni .
#
#   - xxmaj gyerünk - kiáltott fel xxmaj smith - , már nagyon szeretnék ott járni , ahová
#   ember még eddig nem tette a lábát !
#
#   a xxmaj nagy xxmaj sasfészek most mindenesetre nyugodtnak látszott , nem tört fel belőle
#   sem gőz , sem láng .
#
#   xxmaj öt óra felé kocsink megállt a wildoni tanya előtt , amelynek lakói gazdájuk
#   elé jöttek .
#
#   xxmaj az utolsó éjszakát itt xxunk eltölteni .
#
#   a lovakat gyorsan kifogták , és az istállóba vezették , ahol bőséges xxunk
#   várt rájuk , a kocsit pedig a xxunk állították . a kocsis
#   xxunk itt várakozik . xxmaj smith úr egyébként nem kételkedett abban ,
#   hogy felderítő utunk sikeres lesz , és ezt általános megelégedéssel
#   fogadják , amikor majd visszatérünk xxmaj xxunk .
#
#   a wildoni xxunk megnyugtatott minket , hogy a xxmaj nagy xxmaj sasfészekben egy
#   idő óta semmi rendkívüli esemény nem történt .
#
#   a közös asztal mellett együtt vacsoráztunk a xxunk , és éjszaka semmi
#   sem zavarta az álmunkat .
#
#   xxmaj másnap már hajnalban elindultunk a hegy megmászására . a xxmaj nagy xxmaj sasfészek nem
#   nyúlik ezernyolcszáz méter fölé , és ez nem is nagy magasság , ennyi az
#   xxmaj allegheny - hegység xxunk átlagos magassága . xxmaj ezek szerint nem
#   számíthattunk túl nagy xxunk . xxmaj néhány óra alatt xxunk a xxunk
#   legmagasabb csúcsát . xxmaj igaz , hogy útközben akadályokkal találkozhatunk ,
#   szakadékokon kell átkelnünk , s ilyen akadályok xxunk céljából olykor
#   veszélyes és alig járható utat kell választanunk . xxmaj ezt nem tudhattuk előre ,
#   xxunk ezzel a kockázattal számolnia kellett . xxmaj mint tudjuk , erre
#   nézve vezetőink sem tudtak felvilágosítást adni . xxmaj engem az nyugtalanított ,
#   hogy a környéken a xxmaj nagy xxmaj sasfészket mindenki xxunk tartotta . xxmaj de
#   végeredményben erről még soha senki nem győződött meg , és még mindig
#   megvolt az az esélyünk , hogy a levált sziklatömb valami kis rést tett
#   szabaddá a katlant körülvevő sziklafalon .
#
#   - xxmaj akkor hát elindulunk , és jól xxunk - mondta xxmaj smith úr , miután aznap
#   először rágyújtott a xxunk , amit egyébként naponta hússzor tett meg . -
#   xxmaj és majd meglátjuk , hogy a hegy megmászására hosszabb vagy rövidebb időre
#   van - e szükségünk ...
#
#   - xxmaj bárhogyan is lesz , xxmaj smith úr - kérdeztem - , arra ugyebár xxunk
#   magunkat , hogy a nyomozást xxunk ?
#
#   - xxmaj el bizony , xxmaj strock úr .
#
#   - a főnököm azzal bízott meg , hogy mindenáron tudjam meg ennek az átkozott
#   xxmaj nagy xxmaj sasfészeknek a titkát ...
#
#   - xxmaj meg is tudjuk szépszerével vagy erőszakkal - válaszolt xxmaj smith úr , és az
#   eget hívta tanúnak ehhez a xxunk - , még akkor is , ha a hegy
#   belsejébe kell ezért xxunk .
#
# ...
#   meghozta a hírt , hogy egyetlen fia xxunk áldozatául esett , amely betegség
#   éppen akkor érte utol , mikor hajóra akart szállni , hogy xxunk . e
#   balszerencse révén xxmaj xxunk egy csapásra gazdag lett , s vele xxmaj xxunk és a
#   falusi kislány is , általa pedig a gazdagság és mindennemű xxunk
#   esküdt ellensége , a vad xxunk , xxmaj xxunk is !
#
#   xxmaj xxunk korát tekintve most már elkésett dolog lett volna , és nem is bírta
#   volna a jog szerinti xxunk járó xxunk és kínt , hogy
#   xxunk számára a társadalom jó véleményét . xxmaj neki csupán igen kevés
#   ember szeretetére volt szüksége , nem pedig ismeretlen sokaknak xxunk
#   vagy tiszteletére . xxmaj az utóbbit talán még meg lehetett volna nyerni számára ,
#   ha azok , akikre a jóléte feletti őrködés xxunk , tanácsosnak tartották
#   volna azt , hogy a múlt emlékeinek gyötrelmes xxunk xxunk ,
#   amikor számára egyedül a gyengéd xxunk és xxunk lehetett
#   megnyugvás . xxmaj arra , amit szenvedett , nincs elégtétel . xxmaj az elégtétel szánalmas
#   xxunk , amelyet a világ minden bizonnyal két kézzel adott volna - ily
#   xxunk xxunk a pokol kínjai után , melyek alaposan elvégezték pusztító
#   hatásukat - , csak xxunk lett volna jó , arra , hogy xxunk nevetést
#   xxunk , mint xxunk szegény xxmaj xxunk életében valaha is képes volt . xxmaj való
#   igazság ( és szomorú igazság lenne , ha nem lennének azok a magasabb
#   remények , amelyek belőle fakadnak ) , hogy egyetlen nagy bűn sem tehető soha
#   jóvá halandó életünkben , akár xxunk azt , akár szenvedünk miatta . xxmaj az
#   idő , a körülmények szakadatlan változása , valamint a halál minden időben
#   alkalmatlan , elkerülhetetlen xxunk megakadályozzák a jóvátételt . xxmaj ha
#   hosszú évek múltán mégis jogos elismerését xxunk xxunk , már
#   nincs mit xxunk vele . xxmaj jobb orvosság a xxunk , ha csendesen
#   továbbmegy , messze maga mögött hagyván azt , amit egykor xxunk
#   érzett .
#
#   a xxmaj xxunk bíró halála okozta megrázkódtatás hosszú időn át xxunk és
#   végül is jótékony hatással volt xxmaj xxunk . xxmaj az a kegyetlen , erőszakos ember
#   xxmaj xxunk xxunk volt . xxmaj egyetlenegyszer sem tudott szabadon lélegzetet
#   venni , míg belül volt kóros hatásának körén . a szabadság xxunk , amint
#   azt xxmaj xxunk xxunk xxunk tapasztaltuk , elsőnek reszkető
#   xxunk okozott . xxmaj de mikor ez elhagyta , akkor sem süllyedt vissza korábbi
#   tunya , közömbös xxunk . xxmaj igaz , soha közelébe se ért annak , aminek
#   ígéretét képességei magukba hordták . xxmaj mégis elég xxunk neki ahhoz ,
#   hogy részben fény xxunk xxunk , s részleteiben xxunk az a
#   fenséges báj , amelyet összetörtek benne ; és ugyanolyan mély , bár nem
#   annyira szomorú érdeklődést ébresztett iránta , mint eddig . xxmaj xxunk
#   tetszett , hogy boldog . xxmaj ha jutna még időnk életének egy napját leírni , oly
#   sok szép tárgy között , melyek kedveztek a szépség iránti szeretetének ,
#   ehhez a naphoz képest a leírt kerti képek , amelyek pedig oly kedvesek
#   voltak neki akkor - xxunk , xxunk xxunk . xxmaj mindjárt azután ,
#   hogy vagyoni helyzetük így megváltozott , xxmaj xxunk , xxmaj xxunk és a kis xxmaj xxunk
#   a művész erős xxunk úgy határozott , hogy xxunk az öreg , fojtó
#   xxunk xxunk házból , és legalábbis egyelőre , a megboldogult xxmaj xxunk
#   bíró elegáns vidéki házát választják lakóhelyül . xxmaj xxunk és családját
#   már előbb xxunk , ahol is a két tyúk fáradhatatlanul xxunk a sok
#   tojást azzal a nyilvánvaló reménnyel , hogy kötelesség xxunk és
#   xxunk megfelelően nevezetes fajuk a jövőben jobb
#   körülmények közt fog xxunk , mint az elmúlt száz esztendő alatt . xxmaj azon a
#   napon , amelyre xxunk tervezték , történetünk főbb szereplői ,
#   beleértve a jó öreg xxmaj xxunk bácsit is , összegyűltek a xxunk ház
#   xxunk .
#
#   - a villa valóban igen szép lehet , amennyire az xxunk látni -
#   jegyezte meg xxmaj xxunk , amikor a társaság azt beszélte meg , hogy hogyan
#   xxunk be a jövőben . - xxmaj de csodálkozom , hogy a megboldogult bíró , hisz
#   oly jómódú volt , és oly valószínűnek tarthatta , hogy gazdagságát saját
#   xxunk hagyja majd , hogyan nem látta be , mennyivel xxunk lenne ily
#   xxunk családi házat inkább kőből xxunk , mint fából . xxmaj akkor , ha
#   minden nemzedék változtatott volna is a ház xxunk , saját ízlésének és
#   xxunk megfelelően , külseje az évek múltán tiszteletre méltó
#   xxunk is egyre szebb lett volna , ily módon az xxunk azt az
#   érzetét keltve , amelyet minden pillanatnyi boldogság elengedhetetlen
#   xxunk tartok .
#
#   - xxmaj nohát - kiáltott fel xxmaj xxunk , amint csodálkozva , de egyben jól xxunk , a
#   művész arcába nézett - , igazán különös , hogy változnak az elvei ! xxmaj xxunk
#   akar , és még mit nem ! xxmaj két vagy három hete sincs , hogy azt szerette volna ,
#   ha az emberek olyan könnyű és átmeneti xxunk élnének , mint egy
#   xxunk !
#
#   - xxmaj jaj , xxmaj xxunk , hiszen megmondtam , hogy így lesz ! - szólt a művész félig
#   bánatos , félig vidám mosollyal . - xxmaj lám , máris xxunk lettem , pedig
#   mindent inkább el tudtam volna képzelni . xxmaj és ezt különben sem lehet sehogy
#   megbocsátani ebben a házban , amelyben oly sok öröklött szerencsétlenség élt
#   tovább , s itt , a xxunk xxunk tekintete előtt , aki épp e
#   magatartás által tette önmagát oly hosszú időre nemzetségének rossz
#   xxunk .
#
#   - ó , az a kép ! - szólt xxmaj xxunk , és mintha most is összeborzadt volna komor
#   tekintetétől . - xxmaj valahányszor ránézek , egy régi , homályba vesző emlék
#   kísért , amelyet képtelen vagyok pontosan felidézni . xxmaj mintha csak így szólna :
#   gazdagság ! - határtalan gazdagság ! - elképzelhetetlen gazdagság ! xxmaj úgy tűnik ,
#   mintha gyermek lettem volna , vagy ifjú , amikor a kép szólt hozzám , gazdag
#   titkot mondott , vagy talán inkább kinyitotta előttem a kezét , melyben
#   rejtett xxunk szóló írásos okmányt tartott . xxmaj de mostanában olyan
#   homályos előttem minden , ami rég történt ! xxmaj vajon mi lehetett ez az álom ?
#
#   - xxmaj talán én xxunk - válaszolta xxmaj xxunk . - xxmaj nézzék csak , száz az
#   egyhez , hogy aki nem ismeri a titkát , sohasem érinti meg ezt a xxunk .
#
#   - ó , titkos rugó ! - kiáltott fel xxmaj xxunk ! - most már emlékszem ! - xxmaj egyszer
#   már rátaláltam , egy nyári délutánon , amikor tétlenül és álmodozva
#   bolyongtam a házban . xxmaj de nem jut eszembe , hogy is volt .
#
#   a művész megérintette ujjával a szerkezetet , amelyre felhívta a
#   figyelmüket . xxmaj régebben ilyen xxunk biztosan előreugrott volna az arckép .
#   xxmaj mivel azonban ily sokáig volt titokban s xxunk kívül , hát az egész
#   gépezetet megette a rozsda ; és így xxmaj xxunk xxunk xxunk a kép meg a
#   keret mindenestül xxunk , s lezuhant a padlóra . xxmaj ekkor a xxunk egy
#   xxunk xxunk vált láthatóvá , s benne valamely tárgy , amelyet úgy
#   xxunk a századok pora , hogy nem lehetett azonnal felismerni : egy
#   xxunk xxunk volt . xxmaj xxunk xxunk , és egy régi - régi
#   okiratot tárt xxunk elé , amely több indián törzsfő xxunk ellátva ,
#   örök időkre xxmaj xxunk ezredes és utódai birtokának nyilvánított egy óriási
#   kiterjedésű birtokot xxmaj amerika keleti részén .
#
#   - xxmaj íme , ez az a pergamen , amelynek xxunk a szépséges xxmaj alice
#   xxmaj xxunk el kellett xxunk boldogságát és életét - szólt a művész ,
#   xxunk hivatkozva . - xxmaj ez az a kincs , amelyet a xxmaj xxunk hiába
#   kerestek , míg valamit is ért , és most , hogy megtalálják , rég elvesztette
#   már minden értékét .
#
#   - xxmaj szegény xxmaj xxunk xxunk ez vezette hát félre ! - kiáltott fel xxmaj xxunk .
#   - xxmaj fiatal korunkban , mikor együtt voltak , xxmaj xxunk biztosan előadta neki ezt
#   a xxunk , xxunk . xxmaj sokat bolyongott keresztül - kasul a házban ,
#   és minden xxunk bevilágította szép xxunk . xxmaj szegény xxmaj xxunk meg ,
#   aki mindent olyan komolyan vett , azt gondolta , hogy a bátyám xxunk a
#   xxunk vagyonára . xxmaj még mikor meghalt is azt hitte !
#
#   - xxmaj de hát hogy jött rá erre a titokra ? - kérdezte xxmaj xxunk xxmaj xxunk - től
#   félhangosan .
#
#   - xxmaj drága xxmaj xxunk - szólt xxmaj xxunk - , nem tudom , mit érez , ha a xxmaj xxunk nevet
#   hallja ? xxmaj ami ezt a titkot illeti , ez egyetlen xxunk , mely xxunk rám
#   maradt . xxmaj előbb kellett volna talán megmondanom ( csakhogy attól tartottam ,
#   xxunk ) , hogy a bűnnek és xxunk ebben a hosszú xxunk
#   én az öreg xxunk xxunk , és valószínűleg csak ugyanannyi a
#   xxunk , amennyi az övé volt , xxunk . xxmaj az akasztófára jutott
#   xxmaj xxunk xxmaj xxunk fia , az xxunk , e ház építése közben alkalmat talált
#   arra , hogy a falba xxunk azt a titkos xxunk , és elrejtse benne az indián
#   xxunk , amely a végtelen keleti területeket a xxmaj xxunk
#   juttatta . xxmaj ilyenformán a xxmaj xxunk xxmaj xxunk xxunk vesztegették el hatalmas
#   xxunk .
#
#   - xxmaj xxunk meg - szólalt meg xxmaj xxunk bácsi - alighanem az egész xxunk
#   annyit sem ér már , mint egy ember része a xxunk .
#
#   - xxmaj xxunk bácsi ! - kiáltott xxmaj xxunk , kezébe véve a foltozott ruhájú filozófus
#   kezét . - xxmaj ne is xxunk többé a xxunk ! xxmaj sohasem kell xxunk , ameddig él !
#   a mi új xxunk van egy házikó , a legszebb sárgásbarna színű házacska ,
#   amit valaha látott , igazán a xxunk kis ház a világon , éppen , mintha
#   xxunk lenne - azt xxunk és xxunk külön magának . xxmaj és
#   semmi dolga nem lesz , épp csak amihez kedve van , s örülhet a szép napnak
#   reggeltől estig , xxmaj xxunk bátyámat meg folyvást xxunk a sok bölcs és
#   kedves beszéddel , ami az ajkáról ömlik !
#
#   - ó , kedves gyermekem - szólt a jó xxmaj xxunk bácsi egészen elérzékenyülve - ,
#   ha fiatalemberhez szólna így , mint hozzám , szegény öreghez , annak a szíve
#   bizony nem lenne nagyobb biztonságban , mint az én xxunk ! s úgy
#   éljek ! - akkorát sóhajtottam most , hogy igazán leszakadt az utolsó
#   xxunk . xxmaj de hát bánja a kánya ! xxmaj soha életemben nem sóhajtottam ilyen
#   boldogan , mintha csak mennyei levegőt szívott volna a tüdőm ! xxmaj nos , xxmaj xxunk
#   kisasszony ! xxmaj alighanem meg fogják érezni a xxunk a környező kertekben
#   meg a hátsó ajtók tájékán , és azt hiszem , hogy a xxmaj xxunk utca nem is lesz
#   már a régi az öreg xxmaj xxunk bácsi nélkül , mert én még úgy emlékszem ám rá ,
#   hogy az egyik oldalán xxunk volt , a másikon meg a xxunk ház kertje . xxmaj de
#   hát vagy nekem kell xxunk a xxunk vidéki szállására , vagy a
#   kisasszonynak kell az én xxunk jönni , kettő közül az egyiknek meg kell
#   lennie , a kisasszonyra bízom , melyiket választja .
#
#   - xxmaj jöjjön velünk , xxmaj xxunk bácsi , én is kérem ! - szólt xxmaj xxunk , aki különösen
#   szerette az öreg derűs , nyugalmas , egyszerű szellemét . - xxmaj azt szeretném , ha
#   mindig ott xxunk öt - xxunk távolságra xxunk . xxmaj maga az egyetlen
#   filozófus , akinek a bölcsessége mélyén nem találni egy keserű cseppet sem !
#
#   - xxmaj istenem ! - kiáltott xxmaj xxunk bácsi , aki előtt most derengett fel , miféle
#   ember ő voltaképpen . - xxmaj pedig engem , míg fiatal voltam , mindenki xxunk
#   tartott ! xxmaj úgy látszik , olyan vagyok , mint a xxmaj xxunk - alma , minél tovább
#   megmaradok , annál többet érek . xxmaj bölcs szavaim meg , amiket xxmaj xxunk emleget ,
#   olyanok , mint a sárga xxunk , az sem nyit a forró nyári hónapokban , hanem
#   inkább tépett fű között xxunk , meg a száraz levelek alatt , sokszor még
#   késő xxunk is . xxmaj és én szívesen látom magukat , kedves barátaim , dús
#   xxunk , akár meg is xxunk , ha kell .
#
#   xxmaj ekkor egy egyszerű , de formás sötétzöld hintó állt meg a régi xxunk
#   töredezett homlokzata előtt . a kis társaság kilépett a kapun , és xxmaj xxunk
#   bácsi kivételével , aki csak néhány nap múlva készült utánuk menni ,
#   valamennyien beszálltak a hintóba . xxmaj jókedvűen beszélgettek és nevettek - s
#   ahogyan gyakran megesik , olyan pillanatokban , amikor talán érzelemtől
#   kellene remegni xxunk - , xxmaj xxunk és xxmaj xxunk is csak úgy vettek
#   búcsút atyáik házától , alig több megindultsággal , mint hogyha délután
#   xxunk ide teázni . a kocsi és a két szürke ló szokatlan látványa
#   sok gyereket xxunk köréjük . xxmaj mikor xxmaj xxunk megismerte köztük a kis xxmaj xxunk
#   xxmaj higginst , a zsebébe nyúlt , és a kis xxunk , első és xxunk
#   xxunk , annyi ezüstpénzt nyomott a markába , hogy xxunk
#   xxunk gyomrát annyiféle xxunk állattal xxunk be ,
#   ahány egykor xxmaj noé xxunk szállott .
#
#   xxmaj két ember ment arra , épp amikor a hintó elindult .
#
#   - xxmaj no , xxmaj xxunk - mondta az egyik - , mit szólsz ehhez , az én feleségemnek is
#   három hónapig volt xxunk , és öt xxunk odaveszett a
#   xxunk . xxmaj az öreg xxmaj xxunk kisasszony is körülbelül ugyanannyi ideig
#   próbálkozott a xxunk , de most pár xxunk xxunk el a xxunk ,
#   ha nemcsak az ő részét számítjuk , hanem a xxmaj xxunk és xxmaj xxunk xxunk is ,
#   sőt , egyesek szerint kétszer annyi van ! xxmaj ha szerencsének nevezed , jó , de ha
#   úgy vesszük , hogy xxmaj isten akarata , sehogy sem tudom megérteni !
#
#   - xxmaj jó kis üzlet - szólt a bölcs xxmaj xxunk - , jó kis üzlet !
#
#   xxmaj xxunk kútja , jóllehet magára hagyták , mégis egész sor xxunk
#   képet xxunk , amelyből xxunk szem xxunk volna xxmaj xxunk és
#   xxmaj xxunk , valamint a legendás xxunk xxunk sorsát és a falusi
#   xxunk , akire kivetette szerelmének xxunk . a xxmaj xxunk szilfa is ,
#   ritkás xxunk , amelyeket még meghagyott a xxunk vihar , titokzatos
#   xxunk suttogott . a bölcs xxmaj xxunk bácsi pedig , mikor lassan xxunk
#   a töredezett homlokzat előtt , mintha szép zenét hallott volna , és úgy
#   képzelte , hogy a bájos xxmaj alice xxmaj xxunk - miután tanúja volt halandó rokonai
#   sok viselt xxunk , elmúlt xxunk és jelen örömének - távozóban még
#   egyszer megérintette ujjaival a xxunk , és xxunk xxunk
#   felszállt lelkének öröme , amint fölfelé szárnyalt a dallam a xxunk
#   házból .
#
#
#
#   .ooo .
#
#
#
#
# y: LMLabelList
# ,,,,
# Path: /home/jupyter/.fastai/data/huwiki/ulmfit_hu/dataset/classical;
#
# Test: None, model=SequentialRNN(
#   (0): AWD_LSTM(
#     (encoder): Embedding(60000, 400, padding_idx=1)
#     (encoder_dp): EmbeddingDropout(
#       (emb): Embedding(60000, 400, padding_idx=1)
#     )
#     (rnns): ModuleList(
#       (0): WeightDropout(
#         (module): LSTM(400, 1152, batch_first=True)
#       )
#       (1): WeightDropout(
#         (module): LSTM(1152, 1152, batch_first=True)
#       )
#       (2): WeightDropout(
#         (module): LSTM(1152, 400, batch_first=True)
#       )
#     )
#     (input_dp): RNNDropout()
#     (hidden_dps): ModuleList(
#       (0): RNNDropout()
#       (1): RNNDropout()
#       (2): RNNDropout()
#     )
#   )
#   (1): LinearDecoder(
#     (decoder): Linear(in_features=400, out_features=60000, bias=True)
#     (output_dp): RNNDropout()
#   )
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function accuracy at 0x7f0d8e8db3b0>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('/home/jupyter/.fastai/data/huwiki/ulmfit_hu/dataset/classical'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[RNNTrainer
# learn: ...
# alpha: 2.0
# beta: 1.0], layer_groups=[Sequential(
#   (0): WeightDropout(
#     (module): LSTM(400, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 1152, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): WeightDropout(
#     (module): LSTM(1152, 400, batch_first=True)
#   )
#   (1): RNNDropout()
# ), Sequential(
#   (0): Embedding(60000, 400, padding_idx=1)
#   (1): EmbeddingDropout(
#     (emb): Embedding(60000, 400, padding_idx=1)
#   )
#   (2): LinearDecoder(
#     (decoder): Linear(in_features=400, out_features=60000, bias=True)
#     (output_dp): RNNDropout()
#   )
# )], add_time=True, silent=False)
